# %% [markdown]
# # EDA: WIG20 Forecasting
#
# Notebook for exploratory data analysis and quick local experiments.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/wig20.csv', parse_dates=['date'])
df.set_index('date', inplace=True)
df['close'].plot(title='WIG20 (synthetic sample)')
plt.show()

# %% [markdown]
# ## How to run training
#
# Run the training script:
# ```
# python src/train_model.py
# ```
